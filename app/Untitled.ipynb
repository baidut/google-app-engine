# %%
# Out:
# loading data...TestImages_Im2MOS
# all samples are in the validation set!
# You can deactivate this warning by passing `no_check=True`.
# DONE loading data TestImages_Im2MOS
# /home/zq/.virtualenvs/fbiqa/lib/python3.6/site-packages/fastai/data_block.py:451: UserWarning: Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.
#   warn("Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.")
# /home/zq/.virtualenvs/fbiqa/lib/python3.6/site-packages/fastai/basic_data.py:259: UserWarning: There seems to be something wrong with your dataset, for example, in the first batch can't access any element of self.train_ds.
# Tried: 781,153,58,333,477...
#   warn(warn_msg)
# 1.1038295

# %%
learn.predict(im)
# Out:
# (FloatItem [1.10383], tensor([1.1038]), tensor([1.1038]))

# %%
# %matplotlib inline
from fastiqa_dev.all import *

path = '.' # path to model file
file = 'images/Picture1.jpg'
im = open_image(file)

data = Im2MOS(TestImages)
model = BodyHeadModel() # RoIPoolModel()
learn = IqaLearner(data, model, path='.') 
learn.predict(im)[0].obj[0]
# Out:
# loading data...TestImages_Im2MOS
# all samples are in the validation set!
# You can deactivate this warning by passing `no_check=True`.
# DONE loading data TestImages_Im2MOS
# /home/zq/.virtualenvs/tmppy36/lib/python3.6/site-packages/fastai/data_block.py:454: UserWarning: Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.
#   warn("Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.")
# /home/zq/.virtualenvs/tmppy36/lib/python3.6/site-packages/fastai/basic_data.py:262: UserWarning: There seems to be something wrong with your dataset, for example, in the first batch can't access any element of self.train_ds.
# Tried: 930,95,312,962,805...
#   warn(warn_msg)
# -0.23424307

# %%
print(qmap.global_score)
# Out:
# 78.96265

# %%
from scipy import *

# %%
# %matplotlib inline
from fastiqa_dev.all import *

path = '.' # path to model file
file = 'images/Picture1.jpg'
im = open_image(file)

data = Im2MOS(TestImages)
model = RoIPoolModel()

learn = RoIPoolLearner(data, model, path='.') 
learn.load('RoIPoolModel-fit(10,bs=120)')

# qmap = learn.predict_quality_map(im, [32, 32])
qmap = learn.predict_quality_map(im, [32, 32])
qmap
# Out:
# loading data...TestImages_Im2MOS
# all samples are in the validation set!
# You can deactivate this warning by passing `no_check=True`.
# DONE loading data TestImages_Im2MOS
# /home/zq/.virtualenvs/tmppy36/lib/python3.6/site-packages/fastai/data_block.py:454: UserWarning: Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.
#   warn("Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.")
# /home/zq/.virtualenvs/tmppy36/lib/python3.6/site-packages/fastai/basic_data.py:262: UserWarning: There seems to be something wrong with your dataset, for example, in the first batch can't access any element of self.train_ds.
# Tried: 661,577,313,432,797...
#   warn(warn_msg)
